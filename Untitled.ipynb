# %%
import sqlite3
import pandas as pd
#!pip install unicodecsv
import unicodecsv as csv
from io import BytesIO
import unicodedata

# %%
steam_games_df = pd.read_csv("db_files/steam_games.csv", encoding = 'utf-8', dtype={'name':str})
steam_games_df.head()
# Out:
#                                                  url types  \
# 0    https://store.steampowered.com/app/379720/DOOM/   app
# 1  https://store.steampowered.com/app/578080/PLAY...   app
# 2  https://store.steampowered.com/app/637090/BATT...   app
# 3    https://store.steampowered.com/app/221100/DayZ/   app
# 4  https://store.steampowered.com/app/8500/EVE_On...   app
#
#                             name  \
# 0                           DOOM
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                         desc_snippet  \
# 0  Now includes all three premium DLC packs (Unto...
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2  Take command of your own mercenary outfit of '...
# 3  The post-soviet country of Chernarus is struck...
# 4  EVE Online is a community-driven spaceship MMO...
#
#                                       recent_reviews  \
# ...

# %%
#remove uneeded rows
delete_labels = ['url', 'types', 'desc_snippet', 'popular_tags', 'game_details', 'languages', 'achievements',
                 'game_description', 'mature_content', ]

# %%
steam_games_df['name'] = steam_games_df['name'].astype('str')
steam_games_df['name'].str.encode('ascii', 'ignore').str.decode('ascii')
#steam_games_df['name'].str.find('Kingdom Come: Deliverance').value_counts()

steam_games_df.loc[steam_games_df['name'] == 'Kingdom Come: Deliverance']

#mask_nonAscii = steam_games_df['name'].map(str.isascii)
#mask_nonAscii.value_counts()
# Out:
#                                                    url types  \
# 352  https://store.steampowered.com/app/379430/King...   app
#
#                           name  \
# 352  Kingdom Come: Deliverance
#
#                                           desc_snippet  \
# 352  Kingdom Come: Deliverance is a story-driven op...
#
#                                         recent_reviews  \
# 352  Mostly Positive,(450),- 72% of the 450 user re...
#
#                                            all_reviews  release_date  \
# 352  Mostly Positive,(27,512),- 74% of the 27,512 u...  Feb 13, 2018
#
#             developer                                          publisher  \
# 352  Warhorse Studios  Warhorse Studios,Deep Silver,Warhorse Studios,...
#
#                                           popular_tags  \
# 352  Medieval,RPG,Open World,Realistic,Singleplayer...
#
#                                           game_details  \
# 352  Single-player,Steam Achievements,Full controll...
#
# ...

# %%
steam_games_df.dtypes
#steam_games_df['name'] = steam_games_df['name'].astype('|S')
# Out:
# url                          object
# types                        object
# name                         object
# desc_snippet                 object
# recent_reviews               object
# all_reviews                  object
# release_date                 object
# developer                    object
# publisher                    object
# popular_tags                 object
# game_details                 object
# languages                    object
# achievements                float64
# genre                        object
# game_description             object
# mature_content               object
# minimum_requirements         object
# recommended_requirements     object
# original_price               object
# discount_price               object
# dtype: object

# %%
# Create the connection
#cnx = sqlite3.connect(r'C:\Users\pwitw\Homework repositories\ETL-Project\db_files\KS-Steam-Connection-201801.sqlite')

# create the dataframe from a query
#ksReleased = pd.read_sql_query("SELECT * KSreleased", cnx)
